# %%
import numpy as np

# %%
# 这个库可以在电脑上显示和绘制图像
import matplotlib.pyplot as plt
# %matplotlib inline
#

# %%
# 用这个库显示图像
from PIL import Image

# %%
pic = Image.open('R.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1200>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1200, 1920, 3)

# %%
# 转换为数组的图像
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
pic_red
# Out:
# array([[[25, 25, 25],
#         [24, 24, 24],
#         [25, 25, 25],
#         ...,
#         [13, 16, 31],
#         [14, 17, 32],
#         [18, 21, 36]],
#
#        [[25, 25, 25],
#         [24, 24, 24],
#         [25, 25, 25],
#         ...,
#         [12, 15, 30],
#         [13, 16, 31],
#         [17, 20, 35]],
#
#        [[24, 24, 24],
#         [24, 24, 24],
#         [23, 23, 23],
#         ...,
#         [13, 16, 31],
#         [13, 16, 31],
#         [16, 19, 34]],
#
#        ...,
#
#        [[91, 90, 88],
#         [88, 87, 85],
#         [86, 85, 83],
#         ...,
#         [79, 79, 79],
#         [74, 74, 74],
#         [71, 71, 71]],
#
#        [[92, 91, 89],
#         [90, 89, 87],
#         [89, 88, 86],
#         ...,
#         [84, 84, 84],
#         [79, 79, 79],
#         [74, 74, 74]],
#
#        [[93, 92, 90],
#         [91, 90, 88],
#         [91, 90, 88],
#         ...,
#         [83, 83, 83],
#         [74, 74, 74],
#         [67, 67, 67]]], dtype=uint8)

# %%
pic_red[:,:,1]
# Out:
# array([[25, 24, 25, ..., 16, 17, 21],
#        [25, 24, 25, ..., 15, 16, 20],
#        [24, 24, 23, ..., 16, 16, 19],
#        ...,
#        [90, 87, 85, ..., 79, 74, 71],
#        [91, 89, 88, ..., 84, 79, 74],
#        [92, 90, 90, ..., 83, 74, 67]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
pic_red[:,:,0]=0
pic_red[:,:,2]=0
plt.imshow(pic_red)
